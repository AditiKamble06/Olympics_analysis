# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Olympic_Athlete_Event_Results.csv')

# %%
df.tail()
# Out:
#                      edition  edition_id country_noc      sport  \
# 316829  2022 Winter Olympics          62         NED  Bobsleigh
# 316830  2022 Winter Olympics          62         SVK  Bobsleigh
# 316831  2022 Winter Olympics          62         KOR  Bobsleigh
# 316832  2022 Winter Olympics          62         JAM  Bobsleigh
# 316833  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                  event  result_id                     athlete  athlete_id pos  \
# 316829  Monobob, Women   19019671              Karlien Sleper      148662  16
# 316830  Monobob, Women   19019671          Viktória Čerňanská      138683  17
# 316831  Monobob, Women   19019671                  Kim Yu-Ran      137542  18
# 316832  Monobob, Women   19019671  Jazmine Fenlator-Victorian      128682  19
# 316833  Monobob, Women   19019671                Lidiya Hunko      149047  20
#
#        medal  isTeamSport
# 316829   NaN        False
# 316830   NaN        False
# 316831   NaN        False
# 316832   NaN        False
# 316833   NaN        False

# %%
season=df['edition'].values

# %%
df['Season'] = df['edition'].str.extract(r'(Summer|Winter)')

# %%
df.head()
# Out:
#                 edition  edition_id country_noc      sport            event  \
# 0  1908 Summer Olympics           5         ANZ  Athletics  100 metres, Men
# 1  1908 Summer Olympics           5         ANZ  Athletics  400 metres, Men
# 2  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 3  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 4  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
#
#    result_id          athlete  athlete_id        pos medal  isTeamSport  \
# 0      56265  Ernest Hutcheon       64710        DNS   NaN        False
# 1      56313     Henry Murray       64756        DNS   NaN        False
# 2      56338    Harvey Sutton       64808  3 h8 r1/2   NaN        False
# 3      56338      Guy Haskins      922519        DNS   NaN        False
# 4      56338     Joseph Lynch       64735        DNS   NaN        False
#
#    Season
# 0  Summer
# 1  Summer
# 2  Summer
# 3  Summer
# 4  Summer

# %%
df2=pd.read_csv('Olympic_Games_Medal_Tally.csv')

# %%
df2.head()
# Out:
#                 edition  edition_id  year        country country_noc  gold  \
# 0  1896 Summer Olympics           1  1896  United States         USA    11
# 1  1896 Summer Olympics           1  1896         Greece         GRE    10
# 2  1896 Summer Olympics           1  1896        Germany         GER     6
# 3  1896 Summer Olympics           1  1896         France         FRA     5
# 4  1896 Summer Olympics           1  1896  Great Britain         GBR     2
#
#    silver  bronze  total
# 0       7       2     20
# 1      18      19     47
# 2       5       2     13
# 3       4       2     11
# 4       3       2      7

# %%
df2['Season'] = df2['edition'].str.extract(r'(Summer|Winter)')

# %%
df2=df2[df2['Season']=='Summer']

# %%
df2.drop(['edition','edition_id','Season'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#    year        country country_noc  gold  silver  bronze  total
# 0  1896  United States         USA    11       7       2     20
# 1  1896         Greece         GRE    10      18      19     47
# 2  1896        Germany         GER     6       5       2     13
# 3  1896         France         FRA     5       4       2     11
# 4  1896  Great Britain         GBR     2       3       2      7

# %%
df2.groupby('country').sum()[['gold','silver','bronze']].sort_values('gold',ascending=False).reset_index()
# Out:
#                         country  gold  silver  bronze
# 0                 United States  1070     841     744
# 1                  Soviet Union   395     319     296
# 2                 Great Britain   291     323     313
# 3    People's Republic of China   263     199     174
# 4                       Germany   237     264     290
# ..                          ...   ...     ...     ...
# 148                   Mauritius     0       0       1
# 149                       Gabon     0       1       0
# 150                     Eritrea     0       0       1
# 151                   Sri Lanka     0       2       0
# 152                 Afghanistan     0       0       2
#
# [153 rows x 4 columns]

# %%
df3=pd.read_csv('Olympic_Athlete_Bio.csv')

# %%
df3.head()
# Out:
#    athlete_id                name     sex              born  height weight  \
# 0       65649       Ivanka Bonova  Female      4 April 1949   166.0     55
# 1      112510   Nataliya Uryadova  Female     15 March 1977   184.0     70
# 2      114973  Essa Ismail Rashed    Male  14 December 1986   165.0     55
# 3       30359         Péter Boros    Male   12 January 1908     NaN    NaN
# 4       50557      Rudolf Piowatý    Male     28 April 1900     NaN    NaN
#
#                country country_noc  \
# 0             Bulgaria         BUL
# 1   Russian Federation         RUS
# 2                Qatar         QAT
# 3              Hungary         HUN
# 4       Czechoslovakia         TCH
#
#                                          description  \
# 0                 Personal Best: 400 – 53.54 (1980).
# 1                                                NaN
# 2            Personal Best: 10000 – 27:20.97 (2006).
# 3  Between 1927 and 1938, Péter Boros competed as...
# 4  Rudolf Piowaty joined the Czechoslovak militar...
#
#                                        special_notes
# 0                                                NaN
# 1  Listed in Olympians Who Won a Medal at the Eur...
# 2  Listed in Olympians Who Won a Medal at the Asi...
# 3                                                NaN
# 4                                                NaN

# %%
df4=pd.read_csv('Olympic_Games_Medal_Tally.csv')

# %%
merged_df = pd.merge(df, df3, on='athlete_id', how='left')

# %%
merged_df.columns
# Out:
# Index(['edition', 'edition_id', 'country_noc_x', 'sport', 'event', 'result_id',
#        'athlete', 'athlete_id', 'pos', 'medal', 'isTeamSport', 'Season',
#        'name', 'sex', 'born', 'height', 'weight', 'country', 'country_noc_y',
#        'description', 'special_notes'],
#       dtype='object')

# %%
merged_df = merged_df.rename(columns={'country_noc_x': 'country_noc'})

# %%
merged_df.drop(['country_noc_y'],axis=1,inplace=True)

# %%
merged_df.columns
# Out:
# Index(['edition', 'edition_id', 'country_noc', 'sport', 'event', 'result_id',
#        'athlete', 'athlete_id', 'pos', 'medal', 'isTeamSport', 'Season',
#        'name', 'sex', 'born', 'height', 'weight', 'country', 'description',
#        'special_notes'],
#       dtype='object')

# %%
merged_df=merged_df[merged_df['Season']=='Summer']

# %%
merged_df
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316416  2020 Summer Olympics          61         USA  Wrestling
# 316417  2020 Summer Olympics          61         USA  Wrestling
# 316418  2020 Summer Olympics          61         USA  Wrestling
# 316419  2020 Summer Olympics          61         USA  Wrestling
# 316420  2020 Summer Olympics          61         USA  Wrestling
#
#                                       event  result_id              athlete  \
# 0                           100 metres, Men      56265      Ernest Hutcheon
# 1                           400 metres, Men      56313         Henry Murray
# 2                           800 metres, Men      56338        Harvey Sutton
# 3                           800 metres, Men      56338          Guy Haskins
# 4                           800 metres, Men      56338         Joseph Lynch
# ...                                     ...        ...                  ...
# 316416      Featherweight, Freestyle, Women   19009677   Jacarra Winchester
# 316417        Lightweight, Freestyle, Women   19009706       Helen Maroulis
# 316418       Middleweight, Freestyle, Women   19009735        Kayla Miracle
# 316419  Light-Heavyweight, Freestyle, Women   19009764  Tamyra Mensah-Stock
# 316420        Heavyweight, Freestyle, Women   19009793         Adeline Gray
#
#         athlete_id        pos   medal  isTeamSport  Season  \
# 0            64710        DNS     NaN        False  Summer
# 1            64756        DNS     NaN        False  Summer
# 2            64808  3 h8 r1/2     NaN        False  Summer
# 3           922519        DNS     NaN        False  Summer
# 4            64735        DNS     NaN        False  Summer
# ...            ...        ...     ...          ...     ...
# 316416      147307         =5     NaN        False  Summer
# 316417      132194         =3  Bronze        False  Summer
# 316418      147308         12     NaN        False  Summer
# 316419      147310          1    Gold        False  Summer
# 316420      132192          2  Silver        False  Summer
#
#                        name     sex               born  height weight  \
# 0           Ernest Hutcheon    Male       17 June 1889     NaN    NaN
# 1              Henry Murray    Male    14 January 1886     NaN    NaN
# 2             Harvey Sutton    Male   18 February 1882     NaN    NaN
# 3               Guy Haskins    Male   23 December 1883     NaN    NaN
# 4              Joseph Lynch    Male      22 April 1878     NaN    NaN
# ...                     ...     ...                ...     ...    ...
# 316416   Jacarra Winchester  Female    19 October 1992     NaN    NaN
# 316417       Helen Maroulis  Female  19 September 1991   163.0     57
# 316418        Kayla Miracle  Female      26 April 1996     NaN    NaN
# 316419  Tamyra Mensah-Stock  Female    11 October 1992     NaN    NaN
# 316420         Adeline Gray  Female    15 January 1991   173.0     77
#
#                country                                        description  \
# 0          Australasia  Ernest Hutcheon was born in Toowoomba, Queensl...
# 1          Australasia  Henry Murray, a New Zealand national, was one ...
# 2          Australasia  Harvey Sutton was a three-time Australian cham...
# 3          Australasia                                                NaN
# 4          Australasia  Joseph Lynch was a middle-distance runner who ...
# ...                ...                                                ...
# 316416   United States                                                NaN
# 316417   United States                                                NaN
# 316418   United States                                                NaN
# 316419   United States                                                NaN
# 316420   United States                                                NaN
#
#                                             special_notes
# 0       Listed in Olympians Who Played First-Class Cri...
# 1       Listed in Olympians Who Died in Motor Vehicle ...
# 2       Listed in Olympians Who Were Awarded a Rhodes ...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 316416                                                NaN
# 316417  Listed in Olympians Who Won a Medal at the Sum...
# 316418                                                NaN
# 316419                                                NaN
# 316420  Listed in Olympians Who Won a Medal at the Sum...
#
# [254658 rows x 20 columns]

# %%
merged_df['Year'] = merged_df['edition'].str.extract(r'(\d{4})')

# %%
merged_df.head()
# Out:
#                 edition  edition_id country_noc      sport            event  \
# 0  1908 Summer Olympics           5         ANZ  Athletics  100 metres, Men
# 1  1908 Summer Olympics           5         ANZ  Athletics  400 metres, Men
# 2  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 3  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 4  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
#
#    result_id          athlete  athlete_id        pos medal  ...  Season  \
# 0      56265  Ernest Hutcheon       64710        DNS   NaN  ...  Summer
# 1      56313     Henry Murray       64756        DNS   NaN  ...  Summer
# 2      56338    Harvey Sutton       64808  3 h8 r1/2   NaN  ...  Summer
# 3      56338      Guy Haskins      922519        DNS   NaN  ...  Summer
# 4      56338     Joseph Lynch       64735        DNS   NaN  ...  Summer
#
#               name   sex              born height  weight       country  \
# 0  Ernest Hutcheon  Male      17 June 1889    NaN     NaN   Australasia
# 1     Henry Murray  Male   14 January 1886    NaN     NaN   Australasia
# 2    Harvey Sutton  Male  18 February 1882    NaN     NaN   Australasia
# 3      Guy Haskins  Male  23 December 1883    NaN     NaN   Australasia
# 4     Joseph Lynch  Male     22 April 1878    NaN     NaN   Australasia
#
#                                          description  \
# 0  Ernest Hutcheon was born in Toowoomba, Queensl...
# 1  Henry Murray, a New Zealand national, was one ...
# 2  Harvey Sutton was a three-time Australian cham...
# 3                                                NaN
# 4  Joseph Lynch was a middle-distance runner who ...
#
#                                        special_notes  Year
# 0  Listed in Olympians Who Played First-Class Cri...  1908
# 1  Listed in Olympians Who Died in Motor Vehicle ...  1908
# 2  Listed in Olympians Who Were Awarded a Rhodes ...  1908
# 3                                                NaN  1908
# 4                                                NaN  1908
#
# [5 rows x 21 columns]

# %%
merged_df.drop(['edition'],axis=1,inplace=True)

# %%
merged_df.isTeamSport=merged_df.isTeamSport.apply(lambda X: 1 if X==True else 0)

# %%
countries = np.array(merged_df.country)

# %%
countries_str = np.array(countries, dtype=str)

# %%
merged_df.drop(['athlete'],axis=1,inplace=True)

# %%
merged_df.drop(['description','special_notes'],axis=1,inplace=True)

# %%
merged_df.sex.value_counts()
# Out:
# sex
# Male      185582
# Female     69069
# Name: count, dtype: int64

# %%
merged_df.sex=merged_df.sex.apply(lambda X: 'M' if X=='Male' else 'F')

# %%
merged_df.head()
# Out:
#    edition_id country_noc      sport            event  result_id  athlete_id  \
# 0           5         ANZ  Athletics  100 metres, Men      56265       64710
# 1           5         ANZ  Athletics  400 metres, Men      56313       64756
# 2           5         ANZ  Athletics  800 metres, Men      56338       64808
# 3           5         ANZ  Athletics  800 metres, Men      56338      922519
# 4           5         ANZ  Athletics  800 metres, Men      56338       64735
#
#          pos medal  isTeamSport  Season             name sex  \
# 0        DNS   NaN            0  Summer  Ernest Hutcheon   M
# 1        DNS   NaN            0  Summer     Henry Murray   M
# 2  3 h8 r1/2   NaN            0  Summer    Harvey Sutton   M
# 3        DNS   NaN            0  Summer      Guy Haskins   M
# 4        DNS   NaN            0  Summer     Joseph Lynch   M
#
#                born  height weight       country  Year
# 0      17 June 1889     NaN    NaN   Australasia  1908
# 1   14 January 1886     NaN    NaN   Australasia  1908
# 2  18 February 1882     NaN    NaN   Australasia  1908
# 3  23 December 1883     NaN    NaN   Australasia  1908
# 4     22 April 1878     NaN    NaN   Australasia  1908

# %%
merged_df[merged_df.country==' Canada  Trinidad and Tobago']
# Out:
#         edition_id country_noc      sport                      event  \
# 110273          22         CAN  Athletics            400 metres, Men
# 110299          22         CAN  Athletics  4 × 400 metres Relay, Men
# 169149          21         TTO  Athletics            400 metres, Men
# 169151          21         TTO  Athletics  4 × 400 metres Relay, Men
#
#         result_id  athlete_id         pos medal  isTeamSport  Season  \
# 110273      63309       66245   6 h3 r2/4   NaN            0  Summer
# 110299      63424       66245   8 h1 r2/3   NaN            1  Summer
# 169149      62669       66245   8 h2 r2/4   NaN            0  Summer
# 169151      62781       66245  AC h2 r2/3   NaN            1  Summer
#
#                   name sex            born  height weight  \
# 110273  Anton Skerritt   M  3 January 1964   185.0     74
# 110299  Anton Skerritt   M  3 January 1964   185.0     74
# 169149  Anton Skerritt   M  3 January 1964   185.0     74
# 169151  Anton Skerritt   M  3 January 1964   185.0     74
#
#                              country  Year
# 110273   Canada  Trinidad and Tobago  1988
# 110299   Canada  Trinidad and Tobago  1988
# 169149   Canada  Trinidad and Tobago  1984
# 169151   Canada  Trinidad and Tobago  1984

# %%
df5=pd.read_csv('Olympics_Country.csv')

# %%
df5.head()
# Out:
#    noc         country
# 0  AFG     Afghanistan
# 1  ALB         Albania
# 2  ALG         Algeria
# 3  ASA  American Samoa
# 4  AND         Andorra

# %%
merged_df=merged_df.rename(columns={'country_noc':'noc'})

# %%
merged_df1 = pd.merge(merged_df, df5, on='noc', how='left')

# %%
merged_df1.head()
# Out:
#    edition_id  noc      sport            event  result_id  athlete_id  \
# 0           5  ANZ  Athletics  100 metres, Men      56265       64710
# 1           5  ANZ  Athletics  400 metres, Men      56313       64756
# 2           5  ANZ  Athletics  800 metres, Men      56338       64808
# 3           5  ANZ  Athletics  800 metres, Men      56338      922519
# 4           5  ANZ  Athletics  800 metres, Men      56338       64735
#
#          pos medal  isTeamSport  Season             name sex  \
# 0        DNS   NaN            0  Summer  Ernest Hutcheon   M
# 1        DNS   NaN            0  Summer     Henry Murray   M
# 2  3 h8 r1/2   NaN            0  Summer    Harvey Sutton   M
# 3        DNS   NaN            0  Summer      Guy Haskins   M
# 4        DNS   NaN            0  Summer     Joseph Lynch   M
#
#                born  height weight     country_x  Year    country_y
# 0      17 June 1889     NaN    NaN   Australasia  1908  Australasia
# 1   14 January 1886     NaN    NaN   Australasia  1908  Australasia
# 2  18 February 1882     NaN    NaN   Australasia  1908  Australasia
# 3  23 December 1883     NaN    NaN   Australasia  1908  Australasia
# 4     22 April 1878     NaN    NaN   Australasia  1908  Australasia

# %%
merged_df1.drop(['country_x'],axis=1,inplace=True)

# %%
merged_df1=merged_df1.rename(columns={'country_y':'country'})

# %%
merged_df1.country.unique().shape
# Out:
# (230,)

# %%
merged_df1['Year of birth'] = merged_df1['born'].str.extract(r'(\d{4})')

# %%
merged_df1['Year of birth']=pd.to_numeric(merged_df1['Year of birth'], errors='coerce')
merged_df1['Year']=pd.to_numeric(merged_df1['Year'], errors='coerce')

# %%
merged_df1['age']=merged_df1['Year']-merged_df1['Year of birth']

# %%
merged_df1.isnull().sum()
# Out:
# edition_id            0
# noc                   0
# sport                 0
# event                 0
# result_id             0
# athlete_id            0
# pos                   0
# medal            217681
# isTeamSport           0
# Season                0
# name                  7
# sex                   0
# born               5168
# height            74024
# weight            74024
# Year                  0
# country               0
# Year of birth      5325
# age                5325
# dtype: int64

# %%
merged_df1.duplicated().sum()
# Out:
# 1208

# %%
merged_df1=merged_df1.drop_duplicates()

# %%
merged_df1.duplicated().sum()
# Out:
# 0

# %%
oly=pd.concat([merged_df1,pd.get_dummies(merged_df1['medal'],dtype='int8')],axis=1)

# %%
oly.groupby('noc').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()
# Out:
#      noc  Gold  Silver  Bronze
# 0    USA  2727    1474    1302
# 1    URS   848     646     611
# 2    GBR   746     778     720
# 3    GER   613     573     722
# 4    ITA   532     491     482
# ..   ...   ...     ...     ...
# 224  MAS     0      12       7
# 225  MAL     0       0       0
# 226  MAD     0       0       0
# 227  LIE     0       0       0
# 228  AFG     0       0       2
#
# [229 rows x 4 columns]

# %%
oly[oly.isTeamSport==1]
# Out:
#         edition_id  noc       sport              event  result_id  athlete_id  \
# 32               5  ANZ       Rugby         Rugby, Men      31505       11237
# 33               5  ANZ       Rugby         Rugby, Men      31505       11239
# 34               5  ANZ       Rugby         Rugby, Men      31505       11240
# 35               5  ANZ       Rugby         Rugby, Men      31505       11241
# 36               5  ANZ       Rugby         Rugby, Men      31505       11242
# ...            ...  ...         ...                ...        ...         ...
# 255175          61  USA  Water Polo  Water Polo, Women   19001631      132181
# 255176          61  USA  Water Polo  Water Polo, Women   19001631      132183
# 255177          61  USA  Water Polo  Water Polo, Women   19001631      132187
# 255178          61  USA  Water Polo  Water Polo, Women   19001631      147300
# 255179          61  USA  Water Polo  Water Polo, Women   19001631      147301
#
#        pos medal  isTeamSport  Season  ...              born height weight  \
# 32       1  Gold            1  Summer  ...   19 January 1880    NaN    NaN
# 33       1  Gold            1  Summer  ...   25 January 1884    NaN    NaN
# 34       1  Gold            1  Summer  ...  17 February 1887    NaN    NaN
# 35       1  Gold            1  Summer  ...  1 September 1881    NaN    NaN
# 36       1  Gold            1  Summer  ...  19 February 1884    NaN    NaN
# ...     ..   ...          ...     ...  ...               ...    ...    ...
# 255175   1  Gold            1  Summer  ...      2 March 1999  183.0     78
# 255176   1  Gold            1  Summer  ...       16 May 1992  176.0     77
# 255177   1  Gold            1  Summer  ...     29 March 1997  186.0     74
# 255178   1  Gold            1  Summer  ...       28 May 1994    NaN    NaN
# 255179   1  Gold            1  Summer  ...   16 January 1997    NaN    NaN
#
#         Year        country  Year of birth   age  Bronze  Gold  Silver
# 32      1908    Australasia         1880.0  28.0       0     1       0
# 33      1908    Australasia         1884.0  24.0       0     1       0
# 34      1908    Australasia         1887.0  21.0       0     1       0
# 35      1908    Australasia         1881.0  27.0       0     1       0
# 36      1908    Australasia         1884.0  24.0       0     1       0
# ...      ...            ...            ...   ...     ...   ...     ...
# 255175  2020  United States         1999.0  21.0       0     1       0
# 255176  2020  United States         1992.0  28.0       0     1       0
# 255177  2020  United States         1997.0  23.0       0     1       0
# 255178  2020  United States         1994.0  26.0       0     1       0
# 255179  2020  United States         1997.0  23.0       0     1       0
#
# [101457 rows x 22 columns]

# %%
oly.drop_duplicates(subset=['sport','event','isTeamSport','country','medal','result_id','pos','Year'],inplace=True)

# %%
oly.drop(['Season'],axis=1,inplace=True)

# %%
medal_tally=oly.groupby('country').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()

# %%
medal_tally['Total']=medal_tally['Gold']+medal_tally['Silver']+medal_tally['Bronze']

# %%
medal_tally.sort_values('Total',ascending=False).reset_index()
# Out:
#      index        country  Gold  Silver  Bronze  Total
# 0        0  United States  1066     840     742   2648
# 1        1   Soviet Union   394     317     294   1005
# 2        2  Great Britain   292     323     312    927
# 3        4        Germany   238     264     290    792
# 4        5         France   231     258     285    774
# ..     ...            ...   ...     ...     ...    ...
# 225    165       Kiribati     0       0       0      0
# 226    118       Cambodia     0       0       0      0
# 227    162    South Sudan     0       0       0      0
# 228    161        Vanuatu     0       0       0      0
# 229    115         Angola     0       0       0      0
#
# [230 rows x 6 columns]

# %%
medal_df=pd.concat([merged_df1,pd.get_dummies(merged_df1['medal'],dtype='int8')],axis=1,)

# %%
medal_df.drop_duplicates(subset=['sport','event','isTeamSport','country','medal','result_id','pos','Year'],inplace=True)

# %%
medal_df.country.unique()
# Out:
# array(['Australasia', 'Bohemia', 'Aruba', 'Bangladesh', 'Bhutan',
#        'American Samoa', 'Antigua and Barbuda', 'Bahrain', 'Benin',
#        'Belize', 'Barbados', 'Albania', 'Angola', 'Afghanistan',
#        'Brunei Darussalam', 'Azerbaijan', 'Armenia', 'Burundi',
#        'Cabo Verde', 'Botswana', 'British Virgin Islands',
#        'Bosnia and Herzegovina', 'Burkina Faso', 'Andorra', 'Cambodia',
#        'Bermuda', 'Bolivia', 'Algeria', 'Cayman Islands',
#        'Central African Republic', 'Comoros', 'Chad', 'Cook Islands',
#        'Cameroon', 'Congo', 'Belarus', "Côte d'Ivoire",
#        'Democratic Republic of the Congo', 'Djibouti', 'Dominica',
#        'Costa Rica', 'Cyprus', 'Equatorial Guinea', 'Eritrea',
#        'El Salvador', "Democratic People's Republic of Korea",
#        'Dominican Republic', 'Colombia', 'Ecuador', 'Croatia',
#        'Federated States of Micronesia', 'Eswatini', 'Chinese Taipei',
#        'Gabon', 'Chile', 'Ethiopia', 'Fiji', 'Czechia', 'Grenada',
#        'Georgia', 'Guam', 'Cuba', 'Guinea Bissau', 'Estonia', 'Ghana',
#        'Guinea', 'East Germany', 'Bulgaria', 'Egypt',
#        'Independent Olympic Athletes', 'Guyana', 'Guatemala', 'Haiti',
#        'Honduras', 'Argentina', 'Belgium', 'Iraq', 'Jordan', 'Indonesia',
#        'Hong Kong, China', 'Brazil', 'Czechoslovakia', 'Kiribati',
#        'Kosovo', 'Iceland', 'Kingdom of Saudi Arabia', 'Denmark',
#        'Israel', 'Austria', "Lao People's Democratic Republic",
#        'Islamic Republic of Iran', 'Kuwait', 'Kyrgyzstan', 'Jamaica',
#        'Lesotho', 'Libya', 'Liberia', 'Kenya', 'Malaya', 'Kazakhstan',
#        'Ireland', 'Marshall Islands', 'Malawi', 'India', 'Maldives',
#        'Madagascar', 'Mauritania', 'Mali', 'Greece', 'Mauritius', 'Malta',
#        'Lebanon', 'Montenegro', 'Lithuania', 'Liechtenstein', 'Malaysia',
#        'Nauru', 'Mozambique', 'Namibia', 'North Borneo', 'Latvia',
#        'Australia', 'North Yemen', 'Myanmar', 'Luxembourg', 'Nepal',
#        'Netherlands Antilles', 'Monaco', 'Nicaragua', 'Niger', 'Finland',
#        'North Macedonia', 'Palau', 'Oman', 'Palestine', 'Mongolia',
#        'Morocco', 'Papua New Guinea', 'Refugee Olympic Team', 'Paraguay',
#        'Panama', 'Rhodesia', 'Qatar', 'Nigeria', 'Pakistan', 'Saar',
#        'Republic of Moldova', 'Peru', 'Rwanda', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Philippines', 'ROC', 'Russian Olympic Committee',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'São Tomé and Príncipe', 'Puerto Rico', 'Canada', 'Mexico',
#        'Serbia and Montenegro', 'Seychelles', 'Hungary', 'Sierra Leone',
#        'South Sudan', 'Serbia', 'San Marino', 'South Yemen', 'Senegal',
#        'Portugal', 'Solomon Islands', 'Somalia', 'South Vietnam',
#        'New Zealand', 'Singapore', 'Suriname', 'Sudan', 'Tajikistan',
#        'Sri Lanka', 'Syrian Arab Republic', 'Germany', 'Slovakia',
#        'Timor-Leste', 'The Gambia', 'Slovenia', 'Togo', 'Tonga',
#        'Turkmenistan', 'Japan', 'Tuvalu', 'The Bahamas',
#        'United Arab Republic', 'Russian Federation',
#        'United Arab Emirates', 'South Africa', 'Thailand',
#        'Trinidad and Tobago', 'Unified Team', 'Unknown', 'Tunisia',
#        'Uganda', 'Norway', 'United Republic of Tanzania',
#        'West Indies Federation', 'Republic of Korea', 'Romania',
#        'Vanuatu', 'Yemen', "People's Republic of China", 'Vietnam',
#        'Netherlands', 'United States Virgin Islands', 'Uzbekistan',
#        'Zambia', 'Great Britain', 'Italy', 'Uruguay', 'Zimbabwe',
#        'Poland', 'France', 'Türkiye', 'Venezuela', 'Ukraine',
#        'Soviet Union', 'West Germany', 'Yugoslavia', 'Spain',
#        'Switzerland', 'Sweden', 'United States'], dtype=object)

# %%
def fetch_medal_tally(df,year,country):
  medal_df=df.drop_duplicates(subset=['sport','event','isTeamSport','country','medal','result_id','pos','Year'],inplace=True)
  flag=0
  if year=='Overall' and country=='Overall':
    temp_df=medal_df
  if year=='Overall' and country!='Overall':
    flag=1
    temp_df=medal_df[medal_df['country']==country]
  if year!='Overall' and country=='Overall':
    temp_df=medal_df[medal_df['Year']==int(year)]
  if year!='Overall' and country!='Overall':
    temp_df=medal_df[(medal_df['Year']==int(year)) & (medal_df['country']==country)]
  if flag==1:
    x=temp_df.groupby('Year').sum()[['Gold','Silver','Bronze']].sort_values('Year').reset_index()
  else:
    x=temp_df.groupby('country').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()


  x['Total']=x['Gold']+x['Silver']+x['Bronze']
  print(x)

# %%
merged_df1['Year'].unique().shape
# Out:
# (29,)

# %%
merged_df1['Year'].unique()
# Out:
# array([1908, 1912, 1900, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016,
#        2020, 1984, 1976, 1972, 1980, 1968, 1936, 1948, 1956, 1960, 1964,
#        1952, 1932, 1924, 1920, 1928, 1904, 1896], dtype=int64)

# %%
df6=pd.read_csv('Olympics_Games.csv')

# %%
merged_df2=pd.merge(merged_df1,df6[['city','edition_id']],on='edition_id',how='left')

# %%
merged_df2['city'].unique().shape
# Out:
# (23,)

# %%
merged_df2['sport'].unique().shape
# Out:
# (92,)

# %%
merged_df2['event'].unique().shape
# Out:
# (855,)

# %%
merged_df2['name'].unique().shape
# Out:
# (130123,)

# %%
merged_df2['country'].unique().shape
# Out:
# (230,)

# %%
merged_df2.columns
# Out:
# Index(['edition_id', 'noc', 'sport', 'event', 'result_id', 'athlete_id', 'pos',
#        'medal', 'isTeamSport', 'Season', 'name', 'sex', 'born', 'height',
#        'weight', 'Year', 'country', 'Year of birth', 'age', 'city'],
#       dtype='object')
